# %%
# Alphabetical order is standard
# We're doing "import superlongname as abbrev" for our laziness - this way we don't have to type out the whole thing each time.

# Python plotting library
import matplotlib.pyplot as plt

# Numerical python library (pronounced "num-pie")
import numpy as np

# Dataframes in Python
import pandas as pd

# Statistical plotting library we'll use
import seaborn as sns

# This is necessary to show the plotted figures inside the notebook -- "inline" with the notebook cells
# %matplotlib inline

# %%
#Read in counts matrix
countsMatrix = pd.read_csv('C:/Users/anbra/Desktop/Single_Cell_MNTB/Data/CellFilter_EndogGenes_TCsPresent.csv', sep = '\t')
countsMatrix
# Out:
#               GeneID  C1_A1.txt.gz  C1_A2.txt.gz  C1_A4.txt.gz  C1_A5.txt.gz  \
# 0      0610005C13Rik      0.000000     15.404772      0.000000      0.000000
# 1      0610006L08Rik      0.000000      0.000000      0.000000      0.000000
# 2      0610007P14Rik     57.389956     90.047069     32.409988     66.571191
# 3      0610009B22Rik     91.626478     62.009658     77.482457     73.908309
# 4      0610009E02Rik      0.000000      0.000000      0.000000      0.000000
# 5      0610009L18Rik      7.775123      0.000000      0.000000      0.000000
# 6      0610009O20Rik      3.503495      9.044760     15.278935      8.863805
# 7      0610010F05Rik     73.674723    148.503513    165.722907     23.523566
# 8      0610010K14Rik      5.711394      0.000000      0.000000      0.000000
# 9      0610012D04Rik      0.000000      0.000000      0.000000      0.000000
# 10     0610012G03Rik    154.875613     62.504900      0.000000     91.881583
# ...

# %%
#Drop TCs
countsMatrix.drop('C1_D6.txt.gz', axis=1, inplace=True)
countsMatrix.drop('C1_E6.txt.gz', axis=1, inplace=True)
countsMatrix.drop('C1_F6.txt.gz', axis=1, inplace=True)
countsMatrix.drop('C2_F7.txt.gz', axis=1, inplace=True)
countsMatrix.drop('C2_G7.txt.gz', axis=1, inplace=True)
countsMatrix.drop('C2_H7.txt.gz', axis=1, inplace=True)
countsMatrix.drop('C3_G6.txt.gz', axis=1, inplace=True)
countsMatrix.drop('C3_H6.txt.gz', axis=1, inplace=True)
countsMatrix.drop('C3_A7.txt.gz', axis=1, inplace=True)
countsMatrix
# Out:
#               GeneID  C1_A1.txt.gz  C1_A2.txt.gz  C1_A4.txt.gz  C1_A5.txt.gz  \
# 0      0610005C13Rik      0.000000     15.404772      0.000000      0.000000
# 1      0610006L08Rik      0.000000      0.000000      0.000000      0.000000
# 2      0610007P14Rik     57.389956     90.047069     32.409988     66.571191
# 3      0610009B22Rik     91.626478     62.009658     77.482457     73.908309
# 4      0610009E02Rik      0.000000      0.000000      0.000000      0.000000
# 5      0610009L18Rik      7.775123      0.000000      0.000000      0.000000
# 6      0610009O20Rik      3.503495      9.044760     15.278935      8.863805
# 7      0610010F05Rik     73.674723    148.503513    165.722907     23.523566
# 8      0610010K14Rik      5.711394      0.000000      0.000000      0.000000
# 9      0610012D04Rik      0.000000      0.000000      0.000000      0.000000
# 10     0610012G03Rik    154.875613     62.504900      0.000000     91.881583
# ...

# %%
#Make GeneID the index
countsMatrix_2 = countsMatrix.set_index(['GeneID'])
countsMatrix_2
# Out:
#                C1_A1.txt.gz  C1_A2.txt.gz  C1_A4.txt.gz  C1_A5.txt.gz  \
# GeneID
# 0610005C13Rik      0.000000     15.404772      0.000000      0.000000
# 0610006L08Rik      0.000000      0.000000      0.000000      0.000000
# 0610007P14Rik     57.389956     90.047069     32.409988     66.571191
# 0610009B22Rik     91.626478     62.009658     77.482457     73.908309
# 0610009E02Rik      0.000000      0.000000      0.000000      0.000000
# 0610009L18Rik      7.775123      0.000000      0.000000      0.000000
# 0610009O20Rik      3.503495      9.044760     15.278935      8.863805
# 0610010F05Rik     73.674723    148.503513    165.722907     23.523566
# 0610010K14Rik      5.711394      0.000000      0.000000      0.000000
# 0610012D04Rik      0.000000      0.000000      0.000000      0.000000
# 0610012G03Rik    154.875613     62.504900      0.000000     91.881583
# 0610025J13Rik      0.000000      0.000000      1.724520      0.000000
# ...

# %%
#Save counts matrix with no TCs
countsMatrix_2.to_csv('C:/Users/anbra/Desktop/Single_Cell_MNTB/Data/CellFilter_EndogGenes_TCsRemoved.csv', sep = '\t')

# %%
list(countsMatrix_2)
# Out:
# ['C1_A1.txt.gz',
#  'C1_A2.txt.gz',
#  'C1_A4.txt.gz',
#  'C1_A5.txt.gz',
#  'C1_B3.txt.gz',
#  'C1_B4.txt.gz',
#  'C1_B5.txt.gz',
#  'C1_C3.txt.gz',
#  'C1_D1.txt.gz',
#  'C1_D2.txt.gz',
#  'C1_D3.txt.gz',
#  'C1_D4.txt.gz',
#  'C1_D5.txt.gz',
#  'C1_E1.txt.gz',
#  'C1_E2.txt.gz',
#  'C1_E4.txt.gz',
#  'C1_F1.txt.gz',
#  'C1_F2.txt.gz',
#  'C1_F4.txt.gz',
#  'C1_F5.txt.gz',
#  'C1_G1.txt.gz',
#  'C1_G2.txt.gz',
#  'C1_G3.txt.gz',
#  'C1_H1.txt.gz',
#  'C1_H2.txt.gz',
#  'C1_H3.txt.gz',
#  'C1_H5.txt.gz',
#  'C2_A1.txt.gz',
#  'C2_A2.txt.gz',
#  'C2_A3.txt.gz',
#  'C2_A4.txt.gz',
#  'C2_A5.txt.gz',
#  'C2_A6.txt.gz',
#  'C2_A7.txt.gz',
#  'C2_B1.txt.gz',
#  'C2_B2.txt.gz',
#  'C2_B3.txt.gz',
#  'C2_B4.txt.gz',
#  'C2_B5.txt.gz',
#  'C2_B6.txt.gz',
#  'C2_B7.txt.gz',
#  'C2_C1.txt.gz',
#  'C2_C2.txt.gz',
#  'C2_C3.txt.gz',
#  'C2_C4.txt.gz',
#  'C2_C5.txt.gz',
#  'C2_C6.txt.gz',
#  'C2_C7.txt.gz',
#  'C2_D1.txt.gz',
#  'C2_D2.txt.gz',
#  'C2_D3.txt.gz',
#  'C2_D4.txt.gz',
# ...
